# %%
import Pkg; Pkg.add("Images")
# Out:
#    Updating registry at `~/.julia/registries/General`
# ######################################################################### 100.0%
#   Resolving package versions...
#   Installed EarCut_jll ─────────────────── v2.1.5+1
#   Installed OpenSpecFun_jll ────────────── v0.5.3+4
#   Installed Images ─────────────────────── v0.23.1
#   Installed SimpleTraits ───────────────── v0.9.3
#   Installed ImageQualityIndexes ────────── v0.2.0
#   Installed Rotations ──────────────────── v1.0.1
#   Installed ComputationalResources ─────── v0.3.2
#   Installed ImageCore ──────────────────── v0.8.18
#   Installed FFTW_jll ───────────────────── v3.3.9+6
#   Installed WoodburyMatrices ───────────── v0.5.3
#   Installed IntervalSets ───────────────── v0.5.1
#   Installed ImageMetadata ──────────────── v0.9.4
#   Installed TiledIteration ─────────────── v0.2.5
#   Installed ImageDistances ─────────────── v0.2.9
#   Installed OffsetArrays ───────────────── v1.4.0
#   Installed IntelOpenMP_jll ────────────── v2018.0.3+0
#   Installed AbstractFFTs ───────────────── v0.5.0
#   Installed MKL_jll ────────────────────── v2020.2.254+0
#   Installed FFTViews ───────────────────── v0.3.1
#   Installed PaddedViews ────────────────── v0.5.6
#   Installed ImageMorphology ────────────── v0.2.9
#   Installed ColorVectorSpace ───────────── v0.8.6
#   Installed ImageTransformations ───────── v0.8.6
#   Installed RangeArrays ────────────────── v0.3.2
#   Installed Ratios ─────────────────────── v0.4.0
#   Installed AxisAlgorithms ─────────────── v1.0.0
#   Installed MappedArrays ───────────────── v0.2.2
#   Installed CompilerSupportLibraries_jll ─ v0.3.4+0
#   Installed ImageAxes ──────────────────── v0.6.7
#   Installed EllipsisNotation ───────────── v0.4.0
#   Installed SpecialFunctions ───────────── v0.10.3
#   Installed CatIndices ─────────────────── v0.2.1
#   Installed MosaicViews ────────────────── v0.2.4
#   Installed ImageShow ──────────────────── v0.2.3
#   Installed AxisArrays ─────────────────── v0.4.3
#   Installed ImageFiltering ─────────────── v0.6.17
#   Installed FFTW ───────────────────────── v1.2.4
#   Installed Graphics ───────────────────── v1.0.2
#   Installed CustomUnitRanges ───────────── v1.0.0
#   Installed IdentityRanges ─────────────── v0.3.1
#   Installed CoordinateTransformations ──── v0.6.0
#   Installed Interpolations ─────────────── v0.12.10
#   Installed ImageContrastAdjustment ────── v0.3.6
# Updating `~/.julia/environments/v1.5/Project.toml`
#   [916415d5] + Images v0.23.1
# Updating `~/.julia/environments/v1.5/Manifest.toml`
#   [621f4979] + AbstractFFTs v0.5.0
#   [13072b0f] + AxisAlgorithms v1.0.0
#   [39de3d68] + AxisArrays v0.4.3
#   [aafaddc9] + CatIndices v0.2.1
#   [c3611d14] + ColorVectorSpace v0.8.6
#   [e66e0078] + CompilerSupportLibraries_jll v0.3.4+0
#   [ed09eef8] + ComputationalResources v0.3.2
#   [150eb455] + CoordinateTransformations v0.6.0
#   [dc8bdbbb] + CustomUnitRanges v1.0.0
#   [5ae413db] ↑ EarCut_jll v2.1.5+0 ⇒ v2.1.5+1
#   [da5c29d0] + EllipsisNotation v0.4.0
#   [4f61f5a4] + FFTViews v0.3.1
#   [7a1cc6ca] + FFTW v1.2.4
#   [f5851436] + FFTW_jll v3.3.9+6
#   [a2bd30eb] + Graphics v1.0.2
#   [bbac6d45] + IdentityRanges v0.3.1
#   [2803e5a7] + ImageAxes v0.6.7
#   [f332f351] + ImageContrastAdjustment v0.3.6
#   [a09fc81d] + ImageCore v0.8.18
#   [51556ac3] + ImageDistances v0.2.9
#   [6a3955dd] + ImageFiltering v0.6.17
#   [bc367c6b] + ImageMetadata v0.9.4
#   [787d08f9] + ImageMorphology v0.2.9
#   [2996bd0c] + ImageQualityIndexes v0.2.0
#   [4e3cecfd] + ImageShow v0.2.3
#   [02fcd773] + ImageTransformations v0.8.6
#   [916415d5] + Images v0.23.1
#   [1d5cc7b8] + IntelOpenMP_jll v2018.0.3+0
#   [a98d9a8b] + Interpolations v0.12.10
#   [8197267c] + IntervalSets v0.5.1
#   [856f044c] + MKL_jll v2020.2.254+0
#   [dbb5928d] + MappedArrays v0.2.2
#   [e94cdb99] + MosaicViews v0.2.4
#   [6fe1bfb0] + OffsetArrays v1.4.0
#   [efe28fd5] + OpenSpecFun_jll v0.5.3+4
#   [5432bcbf] + PaddedViews v0.5.6
#   [b3c3ace0] + RangeArrays v0.3.2
#   [c84ed2f1] + Ratios v0.4.0
#   [6038ab10] + Rotations v1.0.1
#   [699a6c99] + SimpleTraits v0.9.3
#   [276daf66] + SpecialFunctions v0.10.3
#   [06e1c1a7] + TiledIteration v0.2.5
#   [efce3f68] + WoodburyMatrices v0.5.3
#    Building FFTW → `~/.julia/packages/FFTW/DMUbN/deps/build.log`

# %%
Pkg.add("TestImages");
Pkg.add("FileIO");
# using Colors package to access the color spaces
Pkg.add("Colors");
# Out:
#   Resolving package versions...
#   Installed TestImages ─ v1.3.0
# Updating `~/.julia/environments/v1.5/Project.toml`
#   [5e47fb64] + TestImages v1.3.0
# Updating `~/.julia/environments/v1.5/Manifest.toml`
#   [5e47fb64] + TestImages v1.3.0
#   Resolving package versions...
# Updating `~/.julia/environments/v1.5/Project.toml`
#   [5789e2e9] + FileIO v1.4.4
# No Changes to `~/.julia/environments/v1.5/Manifest.toml`
#   Resolving package versions...
# Updating `~/.julia/environments/v1.5/Project.toml`
#   [5ae59095] + Colors v0.12.4
# No Changes to `~/.julia/environments/v1.5/Manifest.toml`

# %%
import Pkg; Pkg.add("ImageIO")
# Out:
#   Resolving package versions...
#   Installed libpng_jll ─ v1.6.37+6
#   Installed CEnum ────── v0.4.1
#   Installed ImageIO ──── v0.3.1
#   Installed PNGFiles ─── v0.3.2
# Updating `~/.julia/environments/v1.5/Project.toml`
#   [82e4d734] + ImageIO v0.3.1
# Updating `~/.julia/environments/v1.5/Manifest.toml`
#   [fa961155] + CEnum v0.4.1
#   [82e4d734] + ImageIO v0.3.1
#   [f57f5aa1] + PNGFiles v0.3.2
#   [b53b4c65] + libpng_jll v1.6.37+6

# %%
import Pkg; Pkg.add("Colors");
# Out:
#   Resolving package versions...
# No Changes to `~/.julia/environments/v1.5/Project.toml`
# No Changes to `~/.julia/environments/v1.5/Manifest.toml`

# %%
using Images, TestImages, Colors
# Out:
# ┌ Info: Precompiling Images [916415d5-f1e6-5110-898d-aaa5f9f070e0]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling TestImages [5e47fb64-e119-507b-a336-dd2b206d9990]
# └ @ Base loading.jl:1278

# %%
import Pkg; Pkg.add("ImageMagick")
# Out:
#   Resolving package versions...
#   Installed JpegTurbo_jll ─── v2.0.1+3
#   Installed Zstd_jll ──────── v1.4.5+2
#   Installed Libtiff_jll ───── v4.1.0+2
#   Installed ImageMagick_jll ─ v6.9.10-12+3
#   Installed ImageMagick ───── v1.1.6
# Updating `~/.julia/environments/v1.5/Project.toml`
#   [6218d12a] + ImageMagick v1.1.6
# Updating `~/.julia/environments/v1.5/Manifest.toml`
#   [6218d12a] + ImageMagick v1.1.6
#   [c73af94c] + ImageMagick_jll v6.9.10-12+3
#   [aacddb02] + JpegTurbo_jll v2.0.1+3
#   [89763e89] + Libtiff_jll v4.1.0+2
#   [3161d3a3] + Zstd_jll v1.4.5+2

# %%
methods(testimage)
# Out:
# # 1 method for generic function "testimage":
# [1] testimage(filename; download_only, ops...) in TestImages at /Users/pranjal27bhardwaj/.julia/packages/TestImages/g3u50/src/TestImages.jl:79

# %%
img = testimage("lighthouse")
# Out:
# ┌ Info: Precompiling ImageMagick [6218d12a-5da1-5696-b52f-db25d2ecc6d1]
# └ @ Base loading.jl:1278
# 512×768 Array{RGB{N0f8},2} with eltype RGB{Normed{UInt8,8}}:
#  RGB{N0f8}(0.361,0.486,0.6)    …  RGB{N0f8}(0.349,0.49,0.529)
#  RGB{N0f8}(0.361,0.486,0.6)       RGB{N0f8}(0.369,0.498,0.58)
#  RGB{N0f8}(0.376,0.514,0.624)     RGB{N0f8}(0.361,0.498,0.608)
#  RGB{N0f8}(0.365,0.498,0.62)      RGB{N0f8}(0.345,0.478,0.588)
#  RGB{N0f8}(0.365,0.498,0.627)     RGB{N0f8}(0.349,0.486,0.596)
#  RGB{N0f8}(0.369,0.502,0.635)  …  RGB{N0f8}(0.365,0.502,0.612)
#  RGB{N0f8}(0.38,0.518,0.635)      RGB{N0f8}(0.365,0.502,0.612)
#  RGB{N0f8}(0.369,0.502,0.635)     RGB{N0f8}(0.376,0.502,0.616)
#  RGB{N0f8}(0.357,0.502,0.627)     RGB{N0f8}(0.373,0.498,0.604)
#  RGB{N0f8}(0.349,0.49,0.62)       RGB{N0f8}(0.373,0.498,0.604)
#  RGB{N0f8}(0.373,0.518,0.643)  …  RGB{N0f8}(0.353,0.494,0.592)
#  RGB{N0f8}(0.388,0.533,0.659)     RGB{N0f8}(0.361,0.498,0.608)
#  RGB{N0f8}(0.38,0.525,0.643)      RGB{N0f8}(0.376,0.514,0.624)
#  ⋮                             ⋱
#  RGB{N0f8}(0.204,0.169,0.137)  …  RGB{N0f8}(0.157,0.188,0.204)
#  RGB{N0f8}(0.169,0.133,0.118)     RGB{N0f8}(0.169,0.196,0.224)
#  RGB{N0f8}(0.149,0.122,0.11)      RGB{N0f8}(0.231,0.271,0.294)
#  RGB{N0f8}(0.153,0.125,0.114)     RGB{N0f8}(0.176,0.216,0.239)
#  RGB{N0f8}(0.188,0.165,0.141)     RGB{N0f8}(0.231,0.271,0.294)
#  RGB{N0f8}(0.31,0.298,0.263)   …  RGB{N0f8}(0.255,0.302,0.333)
#  RGB{N0f8}(0.486,0.498,0.443)     RGB{N0f8}(0.231,0.29,0.318)
#  RGB{N0f8}(0.663,0.682,0.627)     RGB{N0f8}(0.267,0.31,0.353)
#  RGB{N0f8}(0.702,0.745,0.678)     RGB{N0f8}(0.267,0.31,0.353)
#  RGB{N0f8}(0.459,0.486,0.447)     RGB{N0f8}(0.184,0.22,0.247)
#  RGB{N0f8}(0.443,0.467,0.439)  …  RGB{N0f8}(0.18,0.208,0.22)
#  RGB{N0f8}(0.0,0.0,0.0)           RGB{N0f8}(0.0,0.0,0.0)

# %%
# for this image, we see the internal format is stored as RGB
summary(img)
# Out:
# "512×768 Array{RGB{N0f8},2} with eltype RGB{Normed{UInt8,8}}"

# %%
# we can extract a single pixel, and it gets automatically displayed
img[12]
# Out:
# RGB{N0f8}(0.388,0.533,0.659)

# %% [markdown]
# ### Turns out, one of the annoying things about Julia is that everything is 1-indexed. So if you try to access a 0-index pixel in the image, you will get an error.

# %%
img[0,0]
# Out:
# BoundsError: attempt to access 512×768 Array{RGB{N0f8},2} with eltype RGB{Normed{UInt8,8}} at index [0, 0]
#
# Stacktrace:
#  [1] getindex(::Array{RGB{Normed{UInt8,8}},2}, ::Int64, ::Int64) at ./array.jl:810
#  [2] top-level scope at In[23]:1
#  [3] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091
#  [4] execute_code(::String, ::String) at /Users/pranjal27bhardwaj/.julia/packages/IJulia/a1SNk/src/execute_request.jl:27
#  [5] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /Users/pranjal27bhardwaj/.julia/packages/IJulia/a1SNk/src/execute_request.jl:86
#  [6] #invokelatest#1 at ./essentials.jl:710 [inlined]
#  [7] invokelatest at ./essentials.jl:709 [inlined]
#  [8] eventloop(::ZMQ.Socket) at /Users/pranjal27bhardwaj/.julia/packages/IJulia/a1SNk/src/eventloop.jl:8
#  [9] (::IJulia.var"#15#18")() at ./task.jl:356

# %% [markdown]
# ### And directly from the docs: "numbering goes down columns, and then wraps around at the top of the next column, because Julia arrays are stored in "column major" order where the fastest dimension is the first dimension".
#
# ### All Images are actually AbstractArrays, so you can do indexing with [] notation (just like numpy or MATLAB), just remember that it is one-indexed!
