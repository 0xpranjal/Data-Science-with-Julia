# %%
using Plots

# %%
plot()

# %%
x = 1:15; y = rand(15);

# %%
y
# Out:
# 15-element Array{Float64,1}:
#  0.8725339797270009
#  0.5401739256163745
#  0.061634838263288305
#  0.6279663577824754
#  0.5371082621170242
#  0.6154740863730981
#  0.6215064299905162
#  0.012385166037182316
#  0.1164884844702101
#  0.7478096467622937
#  0.6866623370738849
#  0.4378426729347229
#  0.4041417210745675
#  0.9697710734380947
#  0.49077420196298904

# %%
plot(x,y)

# %%
z = rand(15);

# %%
plot!(x,z)

# %%
p = plot(x,y)
plot!(p,x,z)

# %%
plot(x,y,title="One line random values plot")

# %%
plot(x,y,title="One line random values plot", label = "Line chart 1")

# %%
plot(x,y,title="One line random values plot", xlabel = "Line chart 1", ylabel= "Lince chart 2")

# %%
scatter(x,y)

# %%
bar(x,y)

# %%
histogram(y)

# %%
p1 = plot(x,y)
p2 = scatter(x,y)
p3 = bar(x,y)
p4 = histogram(y)

plot(p1,p2,p3,p4)

# %%
y = rand(15,4)
plot(x,y,layout=(4,1))

# %%
using CSV

# %%
iris = CSV.read("iris.csv", normalizenames = true)
# Out:
# 150×5 DataFrame
# │ Row │ sepal_length │ sepal_width │ petal_length │ petal_width │ species   │
# │     │ Float64      │ Float64     │ Float64      │ Float64     │ String    │
# ├─────┼──────────────┼─────────────┼──────────────┼─────────────┼───────────┤
# │ 1   │ 5.1          │ 3.5         │ 1.4          │ 0.2         │ setosa    │
# │ 2   │ 4.9          │ 3.0         │ 1.4          │ 0.2         │ setosa    │
# │ 3   │ 4.7          │ 3.2         │ 1.3          │ 0.2         │ setosa    │
# │ 4   │ 4.6          │ 3.1         │ 1.5          │ 0.2         │ setosa    │
# │ 5   │ 5.0          │ 3.6         │ 1.4          │ 0.2         │ setosa    │
# │ 6   │ 5.4          │ 3.9         │ 1.7          │ 0.4         │ setosa    │
# │ 7   │ 4.6          │ 3.4         │ 1.4          │ 0.3         │ setosa    │
# │ 8   │ 5.0          │ 3.4         │ 1.5          │ 0.2         │ setosa    │
# │ 9   │ 4.4          │ 2.9         │ 1.4          │ 0.2         │ setosa    │
# ...

# %%
plot(iris.sepal_length)

# %%
bar(iris.species, iris.sepal_length)

# %%
scatter(iris.sepal_length, iris.sepal_width)

# %%
histogram(iris.petal_length)
